# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Setup & preprocessing data

# %%
import os, re, math, warnings
import numpy as np
import pandas as pd
import inspect

from sklearn.multioutput import MultiOutputRegressor
from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV
from sklearn.metrics import make_scorer, mean_squared_error
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
import math

warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('/content/drive/MyDrive/duong/STLF/Data/merge_weather_energy_hanoi_20202025_cleaned.csv')
# df = pd.read_csv('/content/drive/MyDrive/STLF/Data/merge_weather_energy_hanoi_20202025_cleaned.csv')
df
# Out:
#        Temperature               Weather  Precipitation  Chance of snow  \
# 0             25.4  Patchy rain possible            0.6             0.0
# 1             25.1         Partly cloudy            0.0             0.0
# 2             24.7  Patchy rain possible            0.0             0.0
# 3             24.5                Cloudy            0.0             0.0
# 4             24.1  Patchy rain possible            0.0             0.0
# ...            ...                   ...            ...             ...
# 47444         26.8         Partly cloudy            0.0             0.0
# 47445         26.5         Partly cloudy            0.0             0.0
# 47446         26.1  Patchy rain possible            0.0             0.0
# 47447         25.6  Patchy rain possible            0.5             0.0
# 47448         25.3  Patchy rain possible            0.1             0.0
#
#        Humidity      Wind  Wind Gust  Wind Degree Wind Direction  Cloud Cover  \
# 0          89.0  2.194444   4.388889        295.0            WNW         89.0
# 1          90.0  2.611111   5.111111        297.0            WNW         34.0
# 2          91.0  2.805556   5.500000        309.0             NW         87.0
# 3          92.0  2.611111   4.888889        325.0             NW         71.0
# 4          93.0  2.305556   4.000000        326.0            NNW        100.0
# ...         ...       ...        ...          ...            ...          ...
# 47444      84.0  1.888889   3.388889        109.0            ESE         56.0
# 47445      86.0  2.388889   4.194444        126.0             SE         52.0
# 47446      88.0  2.388889   4.194444        149.0            SSE         84.0
# 47447      91.0  2.305556   4.111111        152.0            SSE         76.0
# 47448      87.0  2.500000   4.305556        335.0            NNW        100.0
#
#        Visibility            timestamp  is_weekend  season is_holiday  \
# 0             9.0  2020-01-01 00:00:00           0  winter      False
# 1            10.0  2020-01-01 01:00:00           0  winter      False
# 2            10.0  2020-01-01 02:00:00           0  winter      False
# 3            10.0  2020-01-01 03:00:00           0  winter      False
# 4            10.0  2020-01-01 04:00:00           0  winter      False
# ...           ...                  ...         ...     ...        ...
# 47444        10.0  2025-05-30 20:00:00           0  spring      False
# 47445        10.0  2025-05-30 21:00:00           0  spring      False
# 47446        10.0  2025-05-30 22:00:00           0  spring      False
# 47447         9.0  2025-05-30 23:00:00           0  spring      False
# 47448        10.0  2025-05-31 00:00:00           1  spring      False
#
#        total_consumption_mw
# 0                   1790.10
# 1                   1452.26
# 2                   1483.75
# 3                   1890.07
# 4                   1371.23
# ...                     ...
# 47444               2449.28
# 47445               2554.05
# 47446               1895.41
# 47447               1558.67
# 47448               1362.71
#
# [47449 rows x 16 columns]

# %%
df['Chance of snow'].value_counts()
# Out:
# Chance of snow
# 0.0    47449
# Name: count, dtype: int64

# %%
CAT_COLS   = ['Weather','Wind Direction','season','is_holiday']
EXOG_NUM   = ['Temperature','Precipitation','Humidity',
              'Wind','Wind Gust','Wind Degree','Cloud Cover','Visibility']
HORIZON    = 24                       # forecast t+1…t+24
TARGET_LAGS   = range(1,49)           # lags of target (1…48)
ROLL_WINDOWS  = [3,6,12,24,48]        # rolling windows
EXOG_LAGS     = [0,1,3,6,12,24]       # lags for exogenous vars
TARGET_COL = 'total_consumption_mw'
TIME_COL   = 'timestamp'

# %%
df[TIME_COL] = pd.to_datetime(df[TIME_COL])
df = df.sort_values(TIME_COL).reset_index(drop=True)

# %%
# make sure categoricals are strings
for col in CAT_COLS:
    df[col] = df[col].astype(str)

# %%
# ✓ 0) Sanity: is a GPU attached?
# !nvidia-smi

# ✓ 1) Version check
import xgboost as xgb
print("XGBoost version:", xgb.__version__)

# ✓ 2) Minimal GPU training — if this runs, GPU is working
from sklearn.datasets import make_regression
from xgboost import XGBRegressor
import numpy as np

X, y = make_regression(n_samples=5000, n_features=50, noise=0.1, random_state=42)

xgb_gpu = XGBRegressor(
    tree_method="gpu_hist",       # <-- GPU trainer
    predictor="gpu_predictor",    # <-- GPU predictor
    n_estimators=200,
    max_depth=6,
    learning_rate=0.1,
    random_state=42
)
xgb_gpu.fit(X, y)
print("Trained successfully with GPU!")
# Out:
# Mon Sep 22 17:27:16 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   40C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# XGBoost version: 3.0.5
# Trained successfully with GPU!

# %% [markdown]
# # Feature engineering

# %%
# add calendar/time features
df['hour']      = df[TIME_COL].dt.hour
df['dow']       = df[TIME_COL].dt.dayofweek
df['dom']       = df[TIME_COL].dt.day
df['month']     = df[TIME_COL].dt.month
df['doy']       = df[TIME_COL].dt.dayofyear
df['hour_sin']  = np.sin(2*np.pi*df['hour']/24)
df['hour_cos']  = np.cos(2*np.pi*df['hour']/24)
df['dow_sin']   = np.sin(2*np.pi*df['dow']/7)
df['dow_cos']   = np.cos(2*np.pi*df['dow']/7)
df['doy_sin']   = np.sin(2*np.pi*df['doy']/365.25)
df['doy_cos']   = np.cos(2*np.pi*df['doy']/365.25)

# %%
# 2. feature engineering
# create lagged target features
for L in TARGET_LAGS:
    df[f'y_lag_{L}'] = df[TARGET_COL].shift(L)

# rolling statistics on the target, with one‑step shift to avoid leakage
for W in ROLL_WINDOWS:
    df[f'y_rollmean_{W}'] = df[TARGET_COL].shift(1).rolling(W, min_periods=1).mean()
    df[f'y_rollstd_{W}']  = df[TARGET_COL].shift(1).rolling(W, min_periods=1).std()

# lagged exogenous features
for col in EXOG_NUM:
    for L in EXOG_LAGS:
        df[f'{col}_lag{L}'] = df[col].shift(L)

# multi‑horizon labels
for h in range(1, HORIZON+1):
    df[f'y_t+{h}'] = df[TARGET_COL].shift(-h)

# drop rows with NaNs (from lagging & shifting)no
df_feat = df.dropna().reset_index(drop=True)
df_feat.shape
# Out:
# (47377, 157)

# %% [markdown]
# # Data pre-processing

# %%
np.max(df_feat['timestamp'])
# Out:
# Timestamp('2025-05-30 00:00:00')

# %%
df_feat.shape[0] - 8*7*24
# Out:
# 46033

# %%
# 3. train/valid/test split by time
label_cols   = [f'y_t+{h}' for h in range(1, HORIZON+1)]
feature_cols = [c for c in df_feat.columns if c not in label_cols + [TIME_COL, TARGET_COL]]

X = df_feat[feature_cols]
Y = df_feat[label_cols].values

N        = len(X)
train_end= int(N - 2*8*7*24)
valid_end= int(N - 8*7*24)

X_train, Y_train = X.iloc[:train_end],    Y[:train_end]
X_valid, Y_valid = X.iloc[train_end:valid_end], Y[train_end:valid_end]
X_test,  Y_test  = X.iloc[valid_end:],    Y[valid_end:]

print(X_train.shape, Y_train.shape)
print(X_valid.shape, Y_valid.shape)
print(X_test.shape, Y_test.shape)
# Out:
# (44689, 131) (44689, 24)
# (1344, 131) (1344, 24)
# (1344, 131) (1344, 24)

# %%
np.max(df_feat[:valid_end ]['timestamp'])
# Out:
# Timestamp('2025-04-04 00:00:00')

# %%
# 4. preprocessor: one‑hot encode the 4 categorical columns, pass others through
preprocess = ColumnTransformer(
    [
        ('cat', OneHotEncoder(handle_unknown='ignore', sparse_output=False), CAT_COLS),
        ('num', 'passthrough', [c for c in feature_cols if c not in CAT_COLS])
    ],
    remainder='drop'
)

# %%
# Scorer: average RMSE across 24 horizons (negated for maximization)
# =========================
def avg_neg_rmse(y_true, y_pred):
    y_true = np.asarray(y_true); y_pred = np.asarray(y_pred)
    rmse_per_h = np.sqrt(np.mean((y_true - y_pred)**2, axis=0))
    return -float(np.mean(rmse_per_h))

# %%
scorer = make_scorer(avg_neg_rmse, greater_is_better=True)
scorer
# Out:
# make_scorer(avg_neg_rmse, response_method='predict')

# %%
# train+valid for tuning
X_trv = pd.concat([X_train, X_valid]); Y_trv = np.vstack([Y_train, Y_valid])
tscv = TimeSeriesSplit(n_splits=5)

# %%
tscv = TimeSeriesSplit(n_splits=3)

# %% [markdown]
# # XGBoost tuning

# %%
# =========================
# 3) XGBoost tuning
# =========================
xgb_base = XGBRegressor(objective='reg:squarederror', random_state=42, n_jobs=-1, tree_method='gpu_hist')
xgb_pipe = Pipeline([('prep', preprocess),
                     ('model', MultiOutputRegressor(xgb_base, n_jobs=1))])

xgb_space = {
    'model__estimator__n_estimators':  [600, 800, 1000, 1200],
    'model__estimator__max_depth':     [6, 8, 10],
    'model__estimator__learning_rate': [0.03, 0.05, 0.08],
    'model__estimator__subsample':     [0.7, 0.8, 1.0],
    'model__estimator__colsample_bytree': [0.7, 0.8, 1.0],
    'model__estimator__min_child_weight': [1, 3, 5],
    'model__estimator__gamma':         [0, 0.1, 0.3],
    'model__estimator__reg_alpha':     [0.0, 0.1, 0.5],
    'model__estimator__reg_lambda':    [0.5, 1.0, 2.0],
}

xgb_tuner = RandomizedSearchCV(
    xgb_pipe, xgb_space, n_iter=12, cv=tscv, scoring=scorer,
    random_state=42, n_jobs=-1, verbose=1, refit=True
)
xgb_tuner.fit(X_trv, Y_trv)
print("Best XGB params:", xgb_tuner.best_params_)
print("Best XGB CV avg-RMSE:", -xgb_tuner.best_score_)

# evaluate on held-out test
Y_hat_xgb = xgb_tuner.predict(X_test)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:31:18] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:31:18] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:31:18] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:31:18] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:31:48] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:31:48] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:31:49] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:31:49] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:32:16] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:32:18] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:32:19] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:32:19] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:32:45] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:32:48] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:32:49] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:32:49] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:33:15] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:33:17] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:33:19] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:33:20] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:33:44] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:33:47] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:33:50] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:33:50] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:34:13] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:34:17] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:34:19] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:34:20] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:34:42] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:34:46] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:34:49] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:34:50] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:35:11] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:35:16] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:35:19] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:35:20] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:35:40] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:35:46] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:35:49] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:35:50] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:36:09] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:36:15] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:36:18] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:36:20] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:36:39] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:36:45] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:36:48] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:36:50] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:37:07] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:37:14] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:37:18] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:37:20] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:37:36] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:37:43] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:37:47] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:37:50] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:38:05] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:38:13] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:38:17] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:38:20] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:38:34] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:38:42] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:38:47] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:38:50] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:39:03] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:39:12] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:39:17] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:39:20] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:39:32] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:39:42] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:39:47] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:39:50] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:40:01] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:40:11] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:40:16] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:40:20] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:40:30] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:40:41] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:40:46] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:40:50] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:40:59] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:41:10] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:41:15] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:41:20] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:41:28] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:41:39] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:41:45] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:41:49] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:41:56] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:42:08] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:42:14] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:42:19] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:42:25] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:42:38] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:42:44] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:42:49] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:42:54] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:42:54] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:42:54] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:42:55] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:42:57] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:07] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:07] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:07] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:08] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:08] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:13] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:13] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:13] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:14] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:15] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:17] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:17] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:17] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:18] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:19] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:24] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:33] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:39] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:43] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:46] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:43:57] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:44:02] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:44:07] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:44:09] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:44:21] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:44:26] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:44:31] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:44:32] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:44:44] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:44:50] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:44:55] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:44:55] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:45:08] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:45:14] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:45:18] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:45:19] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:45:31] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:45:38] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [21:45:40] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# ...
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:28:22] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:28:23] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:28:23] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:28:42] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:28:47] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:28:56] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:28:56] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:29:14] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:29:19] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:29:29] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:29:29] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:29:46] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:29:52] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:30:02] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:30:02] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:30:18] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:30:24] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:30:34] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:30:35] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:30:50] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:30:57] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:31:07] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:31:09] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:31:23] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:31:30] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:31:39] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:31:42] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:31:55] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:32:03] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:32:12] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:32:14] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:32:27] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:32:36] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:32:44] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:32:47] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:33:00] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:33:08] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:33:17] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:33:20] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:33:32] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:33:41] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:33:50] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:33:53] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:34:04] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:34:14] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:34:22] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.11/dist-packages/xgboost/core.py:160: UserWarning: [23:34:26] WARNING: /workspace/src/common/error_msg.cc:27: The tree method `gpu_hist` is deprecated since 2.0.0. To use GPU training, set the `device` parameter to CUDA instead.
#
#     E.g. tree_method = "hist", device = "cuda"
#
#   warnings.warn(smsg, UserWarning)

# %%
# =========================
# 3) XGBoost tuning
# =========================

xgb_space = {
    'model__estimator__n_estimators':  [600, 800, 1000],
    'model__estimator__max_depth':     [6, 8],
    'model__estimator__learning_rate': [0.03, 0.05, 0.08],
    'model__estimator__subsample':     [0.7, 0.9],
    'model__estimator__colsample_bytree': [0.7, 0.9],
    'model__estimator__min_child_weight': [1, 3],
    'model__estimator__gamma':         [0, 0.1],
    'model__estimator__reg_alpha':     [0.0, 0.1],
    'model__estimator__reg_lambda':    [0.5, 1.0],
}

xgb_pipe = Pipeline([
    ('prep', preprocess),
    ('model', MultiOutputRegressor(XGBRegressor(objective='reg:squarederror',
                                                tree_method='hist', # 'gpu_hist' if GPU
                                                random_state=42, n_jobs=-1),
                                   n_jobs=1))
])

xgb_tuner = RandomizedSearchCV(
    xgb_pipe, xgb_space, n_iter=12, cv=tscv, scoring=scorer,
    random_state=42, n_jobs=-1, verbose=1, refit=True
)

xgb_tuner.fit(X_trv, Y_trv)
print("Best XGB params:", xgb_tuner.best_params_)
print("Best XGB CV avg-RMSE:", -xgb_tuner.best_score_)

# evaluate on held-out test
Y_hat_xgb = xgb_tuner.predict(X_test)
# Out:
# Fitting 3 folds for each of 12 candidates, totalling 36 fits
# Best XGB params: {'model__estimator__subsample': 0.7, 'model__estimator__reg_lambda': 0.5, 'model__estimator__reg_alpha': 0.0, 'model__estimator__n_estimators': 1000, 'model__estimator__min_child_weight': 3, 'model__estimator__max_depth': 6, 'model__estimator__learning_rate': 0.03, 'model__estimator__gamma': 0.1, 'model__estimator__colsample_bytree': 0.7}
# Best XGB CV avg-RMSE: 320.7161990859629

# %%
print("Best XGB params:", xgb_tuner.best_params_)
print("Best XGB CV avg-RMSE:", -xgb_tuner.best_score_)
# Out:
# Best XGB params: {'model__estimator__subsample': 0.7, 'model__estimator__reg_lambda': 0.5, 'model__estimator__reg_alpha': 0.0, 'model__estimator__n_estimators': 1000, 'model__estimator__min_child_weight': 3, 'model__estimator__max_depth': 6, 'model__estimator__learning_rate': 0.03, 'model__estimator__gamma': 0.1, 'model__estimator__colsample_bytree': 0.7}
# Best XGB CV avg-RMSE: 320.7161990859629

# %%
import joblib

# Save the lgb_tuner object
joblib.dump(xgb_tuner, 'xgb_tuner.pkl')

print("xgb_tuner saved to xgb_tuner.pkl")
# Out:
# xgb_tuner saved to xgb_tuner.pkl

# %%
import joblib
xgb_tuner = joblib.load('/content/drive/MyDrive/duong/STLF/Saved_models/xgb_tuner_1.pkl')

# %%
xgb_tuner.best_params_
# Out:
# {'model__estimator__subsample': 0.7,
#  'model__estimator__reg_lambda': 0.5,
#  'model__estimator__reg_alpha': 0.0,
#  'model__estimator__n_estimators': 1000,
#  'model__estimator__min_child_weight': 3,
#  'model__estimator__max_depth': 6,
#  'model__estimator__learning_rate': 0.03,
#  'model__estimator__gamma': 0.1,
#  'model__estimator__colsample_bytree': 0.7}

# %%
# 70-15-15 split
import xgboost as xgb
# 1) Extract best params from your tuner and map to xgb.train names
bp = xgb_tuner.best_params_
def g(k, default=None): return bp.get(f"model__estimator__{k}", default)

xgb_params = {
    "max_depth":         g("max_depth"),
    "eta":               g("learning_rate"),
    "subsample":         g("subsample"),
    "colsample_bytree":  g("colsample_bytree"),
    "min_child_weight":  g("min_child_weight"),
    "gamma":             g("gamma"),
    "lambda":            g("reg_lambda"),
    "alpha":             g("reg_alpha"),
    "objective":         "reg:squarederror",
    "eval_metric":       "rmse",
    "verbosity":         0,
    #"tree_method":       "gpu_hist",   # set to 'gpu_hist' if you have a GPU
}
num_boost_round = g("n_estimators", 4000)

# 2) Fit encoder on train+valid once; transform arrays for fast training
X_trv_enc  = preprocess.fit_transform(X_trv)
X_test_enc = preprocess.transform(X_test)

# 3) Early-stopping split: last 15% of TRV as eval (keeps time order)
cut = int(0.85 * X_trv_enc.shape[0])
X_tr, X_ev = X_trv_enc[:cut], X_trv_enc[cut:]
Y_tr, Y_ev = Y_trv[:cut],     Y_trv[cut:]

# 4) Train 24 boosters with early stopping
models_xgb = []
for h in range(HORIZON):  # 0..23 for t+1..t+24
    dtrain = xgb.DMatrix(X_tr, label=Y_tr[:, h])
    dvalid = xgb.DMatrix(X_ev, label=Y_ev[:, h])
    booster = xgb.train(
        params=xgb_params,
        dtrain=dtrain,
        num_boost_round=num_boost_round,
        evals=[(dvalid, "valid")],
        early_stopping_rounds=100,
        verbose_eval=False,
    )
    models_xgb.append(booster)

# 5) Predict on test and report metrics
dtest = xgb.DMatrix(X_test_enc)
Y_hat_xgb = np.column_stack([
    m.predict(dtest, iteration_range=(0, m.best_iteration + 1)) for m in models_xgb
])

def safe_mape(y_true, y_pred, eps=1e-6):
    y_true = np.asarray(y_true)
    return np.mean(np.abs((y_true - y_pred) / np.clip(np.abs(y_true), eps, None))) * 100.0

rmse_h_xgb = [math.sqrt(mean_squared_error(Y_test[:, h], Y_hat_xgb[:, h])) for h in range(HORIZON)]
nrmse_h_xgb = [rm / (np.mean(Y_test[:, h]) + 1e-6) * 100 for h, rm in enumerate(rmse_h_xgb)]
mape_h_xgb  = [safe_mape(Y_test[:, h], Y_hat_xgb[:, h]) for h in range(HORIZON)]

print("Per-h RMSE:", [round(x,2) for x in rmse_h_xgb])
print("Avg RMSE:  {:.3f}".format(np.mean(rmse_h_xgb)))
print("Avg nRMSE: {:.2f}%".format(np.mean(nrmse_h_xgb)))
print("Avg MAPE:  {:.2f}%".format(np.mean(mape_h_xgb)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-747453129.py in <cell line: 0>()
#       1 import xgboost as xgb
#       2 # 1) Extract best params from your tuner and map to xgb.train names
# ----> 3 bp = xgb_tuner.best_params_
#       4 def g(k, default=None): return bp.get(f"model__estimator__{k}", default)
#       5
#
# NameError: name 'xgb_tuner' is not defined

# %% [markdown]
# ### Without Z

# %%
# 8lastweeks split
import xgboost as xgb
# 1) Extract best params from your tuner and map to xgb.train names
bp = xgb_tuner.best_params_
def g(k, default=None): return bp.get(f"model__estimator__{k}", default)

xgb_params = {
    "max_depth":         g("max_depth"),
    "eta":               g("learning_rate"),
    "subsample":         g("subsample"),
    "colsample_bytree":  g("colsample_bytree"),
    "min_child_weight":  g("min_child_weight"),
    "gamma":             g("gamma"),
    "lambda":            g("reg_lambda"),
    "alpha":             g("reg_alpha"),
    "objective":         "reg:squarederror",
    "eval_metric":       "rmse",
    "verbosity":         0,
    #"tree_method":       "gpu_hist",   # set to 'gpu_hist' if you have a GPU
}
num_boost_round = g("n_estimators", 4000)

# 2) Fit encoder on train+valid once; transform arrays for fast training
X_trv_enc  = preprocess.fit_transform(X_trv)
X_test_enc = preprocess.transform(X_test)

# 3) Early-stopping split: last 15% of TRV as eval (keeps time order)
cut = int(0.85 * X_trv_enc.shape[0])
X_tr, X_ev = X_trv_enc[:cut], X_trv_enc[cut:]
Y_tr, Y_ev = Y_trv[:cut],     Y_trv[cut:]

# 4) Train 24 boosters with early stopping
models_xgb = []
for h in range(HORIZON):  # 0..23 for t+1..t+24
    dtrain = xgb.DMatrix(X_tr, label=Y_tr[:, h])
    dvalid = xgb.DMatrix(X_ev, label=Y_ev[:, h])
    booster = xgb.train(
        params=xgb_params,
        dtrain=dtrain,
        num_boost_round=num_boost_round,
        evals=[(dvalid, "valid")],
        early_stopping_rounds=100,
        verbose_eval=False,
    )
    models_xgb.append(booster)

# 5) Predict on test and report metrics
dtest = xgb.DMatrix(X_test_enc)
Y_hat_xgb = np.column_stack([
    m.predict(dtest, iteration_range=(0, m.best_iteration + 1)) for m in models_xgb
])

def safe_mape(y_true, y_pred, eps=1e-6):
    y_true = np.asarray(y_true)
    return np.mean(np.abs((y_true - y_pred) / np.clip(np.abs(y_true), eps, None))) * 100.0

rmse_h_xgb = [math.sqrt(mean_squared_error(Y_test[:, h], Y_hat_xgb[:, h])) for h in range(HORIZON)]
nrmse_h_xgb = [rm / (np.mean(Y_test[:, h]) + 1e-6) * 100 for h, rm in enumerate(rmse_h_xgb)]
mape_h_xgb  = [safe_mape(Y_test[:, h], Y_hat_xgb[:, h]) for h in range(HORIZON)]

print("Per-h RMSE:", [round(x,2) for x in rmse_h_xgb])
print("Avg RMSE:  {:.3f}".format(np.mean(rmse_h_xgb)))
print("Avg nRMSE: {:.2f}%".format(np.mean(nrmse_h_xgb)))
print("Avg MAPE:  {:.2f}%".format(np.mean(mape_h_xgb)))
# Out:
# Per-h RMSE: [300.37, 330.13, 292.41, 301.24, 302.94, 292.55, 290.24, 277.7, 290.68, 316.07, 310.6, 313.78, 313.31, 320.77, 311.67, 323.22, 329.68, 309.68, 294.54, 328.63, 311.57, 291.77, 321.41, 326.5]
# Avg RMSE:  308.393
# Avg nRMSE: 12.46%
# Avg MAPE:  9.66%

# %% [markdown]
# ## With future known ahead Z

# %%
# ===== 0) small utility for dtype =====
DTYPE = np.float32

# ===== 1) Build known-ahead future covariates Z for each horizon h=1..H =====
#    Use ONLY features known at t+h: calendar signals + holiday/season (not observed weather).
def build_future_covariates(times, H, df, TIME_COL):
    # times should be the "window end" timestamps: we’ll advance by +h hours
    df_key = df[[TIME_COL, 'is_holiday', 'season']].copy()
    df_key[TIME_COL] = pd.to_datetime(df_key[TIME_COL])
    df_key = df_key.set_index(TIME_COL).sort_index()

    Z_list = []
    for ts in times:
        row = []
        for h in range(1, H+1):
            t_h = pd.Timestamp(ts) + pd.Timedelta(hours=h)
            hour = t_h.hour; dow = t_h.dayofweek; doy = t_h.dayofyear
            v = [
                np.sin(2*np.pi*hour/24), np.cos(2*np.pi*hour/24),
                np.sin(2*np.pi*dow/7),  np.cos(2*np.pi*dow/7),
                np.sin(2*np.pi*doy/365.25), np.cos(2*np.pi*doy/365.25),
                1 if dow>=5 else 0,  # is_weekend
            ]
            # holiday + season one-hots from the calendar row if present
            if t_h in df_key.index:
                hol = str(df_key.loc[t_h, 'is_holiday'])
                sea = str(df_key.loc[t_h, 'season'])
            else:
                hol, sea = "False", None
            # fixed one-hot order for holidays (3-valued) and seasons (4-valued)
            hol_vec = [int(hol=="False"), int(hol=="tet"), int(hol=="national")]
            sea_vec = [int(sea==s) for s in ["winter","spring","summer","autumn"]] if sea is not None else [0,0,0,0]
            v += hol_vec + sea_vec
            row.append(v)
        Z_list.append(row)
    Z = np.array(Z_list, dtype=DTYPE)  # (N, H, Ff)
    return Z

# ===== 2) Build Z for EXACTLY the rows in df_feat (after dropna) =====
# end_times for each training sample correspond to the row's timestamp (window end t)
end_times_all = df_feat[TIME_COL].values
Z_all = build_future_covariates(end_times_all, HORIZON, df=df, TIME_COL=TIME_COL)
# Z_all shape: (N_feat, H, Ff)

# ===== 3) Split Z with the SAME indices as X / Y =====
Z_trv  = Z_all[:valid_end]        # train+valid
Z_test = Z_all[valid_end:]        # held-out test

# ===== 4) Keep your tuned params; we’ll refit with Z appended per horizon =====
import xgboost as xgb
bp = xgb_tuner.best_params_
def g(k, default=None): return bp.get(f"model__estimator__{k}", default)

xgb_params = {
    "max_depth":         g("max_depth"),
    "eta":               g("learning_rate"),
    "subsample":         g("subsample"),
    "colsample_bytree":  g("colsample_bytree"),
    "min_child_weight":  g("min_child_weight"),
    "gamma":             g("gamma"),
    "lambda":            g("reg_lambda"),
    "alpha":             g("reg_alpha"),
    "objective":         "reg:squarederror",
    "eval_metric":       "rmse",
    "verbosity":         0,
    "tree_method":     "gpu_hist",  # enable if you have GPU
}
num_boost_round = g("n_estimators", 1500)  # safe default if not in best_params_

# ===== 5) Encode X once, then append Z[h] slice at training time =====
X_trv_enc  = preprocess.fit_transform(X_trv)   # (N_trv, D_enc)
X_test_enc = preprocess.transform(X_test)      # (N_test, D_enc)

# Early stopping split inside TRV, preserving order
cut = int(0.85 * X_trv_enc.shape[0])
X_tr_enc,  X_ev_enc  = X_trv_enc[:cut],  X_trv_enc[cut:]
Y_tr_all,  Y_ev_all  = Y_trv[:cut],      Y_trv[cut:]
Z_trv_all            = Z_trv             # (N_trv, H, Ff)
Z_tr_all,  Z_ev_all  = Z_trv_all[:cut],  Z_trv_all[cut:]

# ===== 6) Train 24 horizon-specific boosters with Z attached =====
models_xgb = []
for h in range(HORIZON):  # h=0..23 ==> horizons t+1..t+24
    # horizon-specific future covariates slices
    Z_tr_h  = Z_tr_all[:, h, :]   # (N_tr, Ff)
    Z_ev_h  = Z_ev_all[:, h, :]   # (N_ev, Ff)
    Z_te_h  = Z_test[:, h, :]     # (N_test, Ff)

    # concatenate: [encoded original features || future-covariates for this horizon]
    Xtr_h  = np.hstack([X_tr_enc, Z_tr_h]).astype(DTYPE)
    Xev_h  = np.hstack([X_ev_enc, Z_ev_h]).astype(DTYPE)
    Xte_h  = np.hstack([X_test_enc, Z_te_h]).astype(DTYPE)

    dtrain = xgb.DMatrix(Xtr_h, label=Y_tr_all[:, h])
    dvalid = xgb.DMatrix(Xev_h, label=Y_ev_all[:, h])

    booster = xgb.train(
        params=xgb_params,
        dtrain=dtrain,
        num_boost_round=num_boost_round,
        evals=[(dvalid, "valid")],
        early_stopping_rounds=100,
        verbose_eval=False,
    )
    models_xgb.append((booster, Xte_h))  # store Xte_h so we don't rebuild

# ===== 7) Predict test with the horizon-specific features =====
Y_hat_xgb = np.column_stack([
    m.predict(xgb.DMatrix(Xte_h), iteration_range=(0, m.best_iteration + 1))
    for (m, Xte_h) in models_xgb
])

# ===== 8) Metrics (unchanged) =====
def safe_mape(y_true, y_pred, eps=1e-6):
    y_true = np.asarray(y_true)
    return np.mean(np.abs((y_true - y_pred) / np.clip(np.abs(y_true), eps, None))) * 100.0

rmse_h_xgb = [math.sqrt(mean_squared_error(Y_test[:, h], Y_hat_xgb[:, h])) for h in range(HORIZON)]
nrmse_h_xgb = [rm / (np.mean(Y_test[:, h]) + 1e-6) * 100 for h, rm in enumerate(rmse_h_xgb)]
mape_h_xgb  = [safe_mape(Y_test[:, h], Y_hat_xgb[:, h]) for h in range(HORIZON)]

print("Per-h RMSE:", [round(x,2) for x in rmse_h_xgb])
print("Avg RMSE:  {:.3f}".format(np.mean(rmse_h_xgb)))
print("Avg nRMSE: {:.2f}%".format(np.mean(nrmse_h_xgb)))
print("Avg MAPE:  {:.2f}%".format(np.mean(mape_h_xgb)))
# Out:
# Per-h RMSE: [302.92, 324.84, 295.44, 295.63, 298.8, 296.66, 284.81, 269.3, 288.09, 302.5, 307.09, 304.03, 292.25, 326.21, 306.16, 322.76, 327.28, 304.85, 283.7, 324.54, 301.49, 299.43, 329.9, 317.08]
# Avg RMSE:  304.407
# Avg nRMSE: 12.30%
# Avg MAPE:  9.47%

# %% [markdown]
# # LightGBM tuning

# %%
import numpy as np, lightgbm as lgb
X = np.random.rand(1000, 100); y = np.random.rand(1000)
d = lgb.Dataset(X, label=y)
lgb.train({"objective":"regression","device_type":"gpu"}, d, num_boost_round=1)
print("GPU works")
# Out:
# [LightGBM] [Info] This is the GPU trainer!!
# [LightGBM] [Info] Total Bins 25500
# [LightGBM] [Info] Number of data points in the train set: 1000, number of used features: 100
# [LightGBM] [Info] Using GPU Device: Tesla T4, Vendor: NVIDIA Corporation
# [LightGBM] [Info] Compiling OpenCL Kernel with 256 bins...
# [LightGBM] [Info] GPU programs have been built
# [LightGBM] [Info] Size of histogram bin entry: 8
# [LightGBM] [Info] 100 dense feature groups (0.10 MB) transferred to GPU in 0.001087 secs. 0 sparse feature groups
# [LightGBM] [Info] Start training from score 0.498480
# GPU works

# %%
from lightgbm import LGBMRegressor
from sklearn.pipeline import Pipeline
from sklearn.multioutput import MultiOutputRegressor
from sklearn.model_selection import RandomizedSearchCV

# Base estimator
lgb_base = LGBMRegressor(
    objective="regression",
    random_state=42,
    n_jobs=-1,          # let the trees parallelize
    boosting_type="gbdt",
    verbose=-1,
    max_bin=127,
    #device_type="gpu"
)

# Pipeline (avoid double over-parallelization)
lgb_pipe = Pipeline([
    ("prep", preprocess),
    ("model", MultiOutputRegressor(lgb_base, n_jobs=1))  # keep this at 1 if RandomizedSearchCV uses n_jobs=-1
])

# Search space (lean but effective)
lgb_space = {
  "model__estimator__n_estimators": [300, 500, 700],
  "model__estimator__learning_rate":[0.05, 0.08],
  "model__estimator__num_leaves":  [63, 127],
  "model__estimator__max_depth":   [-1, 8],
  "model__estimator__subsample":   [0.7, 0.9],
  "model__estimator__colsample_bytree":[0.7, 0.9],
  "model__estimator__min_child_samples":[20, 40],
  "model__estimator__reg_alpha":   [0.0, 0.1],
  "model__estimator__reg_lambda":  [0.1, 1.0],
}

# Randomized search (fast pass; bump n_iter if you want wider exploration)
lgb_tuner = RandomizedSearchCV(
    lgb_pipe,
    lgb_space,
    n_iter=8,
    cv=tscv,            # your TimeSeriesSplit
    scoring=scorer,     # your avg-neg-RMSE scorer
    random_state=42,
    n_jobs=-1,          # parallelize candidates × folds
    verbose=1,
    refit=True
)

lgb_tuner.fit(X_trv, Y_trv)

print("Best LGB params:", lgb_tuner.best_params_)
print("Best LGB CV avg-RMSE:", -lgb_tuner.best_score_)
# Out:
# Fitting 3 folds for each of 8 candidates, totalling 24 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2950193576.py in <cell line: 0>()
#      47 )
#      48
# ---> 49 lgb_tuner.fit(X_trv, Y_trv)
#      50
#      51 print("Best LGB params:", lgb_tuner.best_params_)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, **params)
#    1022                 return results
#    1023
# -> 1024             self._run_search(evaluate_candidates)
#    1025
#    1026             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1949     def _run_search(self, evaluate_candidates):
#    1950         """Search n_iter candidates from param_distributions"""
# -> 1951         evaluate_candidates(
#    1952             ParameterSampler(
#    1953                 self.param_distributions, self.n_iter, random_state=self.random_state
#
# /usr/local/lib/python3.12/dist-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     968                     )
#     969
# --> 970                 out = parallel(
#     971                     delayed(_fit_and_score)(
#     972                         clone(base_estimator),
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/parallel.py in __call__(self, iterable)
#      75             for delayed_func, args, kwargs in iterable
#      76         )
# ---> 77         return super().__call__(iterable_with_config)
#      78
#      79
#
# /usr/local/lib/python3.12/dist-packages/joblib/parallel.py in __call__(self, iterable)
#    2070         next(output)
#    2071
# -> 2072         return output if self.return_generator else list(output)
#    2073
#    2074     def __repr__(self):
#
# /usr/local/lib/python3.12/dist-packages/joblib/parallel.py in _get_outputs(self, iterator, pre_dispatch)
#    1680
#    1681             with self._backend.retrieval_context():
# -> 1682                 yield from self._retrieve()
#    1683
#    1684         except GeneratorExit:
#
# /usr/local/lib/python3.12/dist-packages/joblib/parallel.py in _retrieve(self)
#    1798                     self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799                 ):
# -> 1800                     time.sleep(0.01)
#    1801                     continue
#    1802
#
# KeyboardInterrupt:

# %%
# ===== LGB final refit with early stopping (continue from your state) =====
import numpy as np, math, lightgbm as lgb
from sklearn.metrics import mean_squared_error

# 1) map best params from tuner to lgb.train
bp = lgb_tuner.best_params_
g  = lambda k, d=None: bp.get(f"model__estimator__{k}", d)

lgb_params = {
    "objective": "regression",
    "metric": "rmse",
    "learning_rate": g("learning_rate", 0.05),
    "num_leaves": g("num_leaves", 127),
    "max_depth": g("max_depth", -1),
    "feature_fraction": g("colsample_bytree", 0.8),   # alias
    "bagging_fraction": g("subsample", 0.8),          # alias
    "bagging_freq": bp.get("model__estimator__subsample_freq", 0),
    "min_data_in_leaf": g("min_child_samples", 20),
    "lambda_l1": g("reg_alpha", 0.0),
    "lambda_l2": g("reg_lambda", 0.1),
    "verbosity": -1,
    "num_threads": -1,
    # Optional GPU:
    "device_type": "gpu",
    # Optional speed knob during refit:
    "max_bin": 255,
}
# let ES find the best iteration (set bigger than tuned n_estimators)
num_boost_round = 4000
early_stopping_rounds = 100

# 2) encode once
X_trv_enc  = preprocess.fit_transform(X_trv)
X_test_enc = preprocess.transform(X_test)

# 3) carve last 15% of TRV as eval set (keep chronological order)
cut = int(0.85 * X_trv_enc.shape[0])
X_tr, X_ev = X_trv_enc[:cut], X_trv_enc[cut:]
Y_tr, Y_ev = Y_trv[:cut],     Y_trv[cut:]

# 4) train 24 boosters with ES
models_lgb = []
for h in range(HORIZON):
    dtr = lgb.Dataset(X_tr, label=Y_tr[:, h])
    dev = lgb.Dataset(X_ev, label=Y_ev[:, h], reference=dtr)
    booster = lgb.train(
        params=lgb_params,
        train_set=dtr,
        num_boost_round=num_boost_round,
        valid_sets=[dev],
        callbacks=[lgb.early_stopping(early_stopping_rounds), lgb.log_evaluation(-1)]
    )
    models_lgb.append(booster)

# 5) predict & metrics
Y_hat_lgb = np.column_stack([m.predict(X_test_enc, num_iteration=m.best_iteration) for m in models_lgb])

def safe_mape(y_true, y_pred, eps=1e-6):
    y_true = np.asarray(y_true)
    return np.mean(np.abs((y_true - y_pred) / np.clip(np.abs(y_true), eps, None))) * 100.0

rmse_h_lgb = [math.sqrt(mean_squared_error(Y_test[:, h], Y_hat_lgb[:, h])) for h in range(HORIZON)]
nrmse_h_lgb = [rm / (np.mean(Y_test[:, h]) + 1e-6) * 100 for h, rm in enumerate(rmse_h_lgb)]
mape_h_lgb  = [safe_mape(Y_test[:, h], Y_hat_lgb[:, h]) for h in range(HORIZON)]

print("Per-horizon RMSE:", [round(x,2) for x in rmse_h_lgb])
print("Avg RMSE:  {:.3f}".format(np.mean(rmse_h_lgb)))
print("Avg nRMSE: {:.2f}%".format(np.mean(nrmse_h_lgb)))
print("Avg MAPE:  {:.2f}%".format(np.mean(mape_h_lgb)))
# Out:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [497]	valid_0's rmse: 262.679
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [549]	valid_0's rmse: 264.763
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [578]	valid_0's rmse: 271.19
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [520]	valid_0's rmse: 273.567
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [805]	valid_0's rmse: 282.022
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [930]	valid_0's rmse: 291.961
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [697]	valid_0's rmse: 299.357
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [916]	valid_0's rmse: 301.068
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [718]	valid_0's rmse: 304.641
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [524]	valid_0's rmse: 308.902
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [762]	valid_0's rmse: 317.758
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [707]	valid_0's rmse: 326.987
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [268]	valid_0's rmse: 328.94
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [473]	valid_0's rmse: 331.844
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [781]	valid_0's rmse: 332.118
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [399]	valid_0's rmse: 338.413
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [592]	valid_0's rmse: 344.226
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [477]	valid_0's rmse: 346.174
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [359]	valid_0's rmse: 357.033
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [495]	valid_0's rmse: 352.283
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [338]	valid_0's rmse: 355.131
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [368]	valid_0's rmse: 354.983
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [627]	valid_0's rmse: 352.32
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [636]	valid_0's rmse: 358.279
# Per-horizon RMSE: [274.6, 285.04, 273.35, 276.21, 281.96, 273.42, 270.18, 261.52, 271.67, 277.64, 276.35, 277.89, 280.05, 284.98, 276.67, 274.92, 275.68, 273.08, 265.77, 281.67, 272.1, 267.45, 286.04, 295.74]
# Avg RMSE:  276.415
# Avg nRMSE: 11.78%
# Avg MAPE:  8.74%

# %%
import os
BASE_DIR = "/content/drive/MyDrive/duong/STLF/Saved_models/lgbm_newsplit" # luongphuc.lpu
# BASE_DIR = "/content/drive/MyDrive/STLF/Saved_models/lgbm_newsplit" # ducan
os.makedirs(BASE_DIR, exist_ok=True)

# %%
import os, json, joblib, numpy as np, gc
from sklearn.model_selection import ParameterSampler
from sklearn.base import clone
from sklearn.pipeline import Pipeline
from sklearn.multioutput import MultiOutputRegressor
from lightgbm import LGBMRegressor

# %%
# ==== config for Drive paths ====
N_ITER = 8  # same as your RandomizedSearchCV
PROGRESS_JSON = os.path.join(BASE_DIR, "lgbm_tune_progress.json")
PARAMS_JSON   = os.path.join(BASE_DIR, "lgbm_param_list.json")  # to keep the same sequence on resume
TRIAL_CKP_FMT = os.path.join(BASE_DIR, "lgbm_checkpoint_trial_{:03d}.pkl")
BEST_MODEL_PKL= os.path.join(BASE_DIR, "lgbm_best_model.pkl")

# %%
# Base estimator
lgb_base = LGBMRegressor(
    objective="regression",
    random_state=42,
    n_jobs=-1,          # let the trees parallelize
    boosting_type="gbdt",
    verbose=-1,
    max_bin=127,
    #device_type="gpu"
)

# Pipeline (avoid double over-parallelization)
lgb_pipe = Pipeline([
    ("prep", preprocess),
    ("model", MultiOutputRegressor(lgb_base, n_jobs=1))  # keep this at 1 if RandomizedSearchCV uses n_jobs=-1
])

# Search space (lean but effective)
lgb_space = {
  "model__estimator__n_estimators": [300, 500, 700],
  "model__estimator__learning_rate":[0.05, 0.08],
  "model__estimator__num_leaves":  [63, 127],
  "model__estimator__max_depth":   [-1, 8],
  "model__estimator__subsample":   [0.7, 0.9],
  "model__estimator__colsample_bytree":[0.7, 0.9],
  "model__estimator__min_child_samples":[20, 40],
  "model__estimator__reg_alpha":   [0.0, 0.1],
  "model__estimator__reg_lambda":  [0.1, 1.0],
}

# ==== build / load param list deterministically ====
if os.path.exists(PARAMS_JSON):
    with open(PARAMS_JSON, "r") as f:
        param_list = json.load(f)
else:
    from sklearn.model_selection import ParameterSampler
    param_list = list(ParameterSampler(lgb_space, n_iter=N_ITER, random_state=42))
    with open(PARAMS_JSON, "w") as f:
        json.dump(param_list, f)

# ==== load progress if exists ====
if os.path.exists(PROGRESS_JSON):
    with open(PROGRESS_JSON, "r") as f:
        prog = json.load(f)
    completed = set(prog.get("completed_indices", []))
    best_score = prog.get("best_score", -np.inf)
    best_params = prog.get("best_params", None)
else:
    completed, best_score, best_params = set(), -np.inf, None
    prog = {"completed_indices": [], "best_score": best_score, "best_params": best_params}

print(f"Resuming: {len(completed)}/{len(param_list)} trials completed.")
print("Checkpoints folder:", BASE_DIR)

# ==== helper: evaluate one param set with your tscv + scorer ====
def cv_score_for_params(params):
    lgb_base = LGBMRegressor(
        objective="regression",
        random_state=42,
        n_jobs=-1,
        boosting_type="gbdt",
        verbose=-1,
        max_bin=127,
        # GPU if available, else comment out:
        #device_type="gpu"
    )
    pipe = Pipeline([
        ("prep", preprocess),
        ("model", MultiOutputRegressor(lgb_base, n_jobs=1))
    ])
    pipe.set_params(**params)

    fold_scores = []
    for fold_idx, (tr_idx, va_idx) in enumerate(tscv.split(X_trv)):
        X_tr, X_va = X_trv.iloc[tr_idx], X_trv.iloc[va_idx]
        Y_tr, Y_va = Y_trv[tr_idx],      Y_trv[va_idx]

        pipe_fold = clone(pipe)
        pipe_fold.fit(X_tr, Y_tr)
        s = scorer(pipe_fold, X_va, Y_va)   # your avg-neg-RMSE scorer
        fold_scores.append(s)
        # free memory between folds
        del pipe_fold; gc.collect()
    return float(np.mean(fold_scores)), pipe  # return mean score and last-fitted pipe

# ==== main loop with Drive checkpoints ====
for i, params in enumerate(param_list):
    if i in completed:
        print(f"Skipping trial {i+1}: already completed.")
        continue

    print(f"\n--- Trial {i+1}/{len(param_list)} ---")
    print("Params:", params)
    try:
        score, fitted_pipe = cv_score_for_params(params)
        print("CV score (avg-neg-RMSE):", score)

        # save trial checkpoint to Drive
        joblib.dump(fitted_pipe, TRIAL_CKP_FMT.format(i+1), compress=3)

        # update best
        if score > best_score:
            best_score = score
            best_params = params
            joblib.dump(fitted_pipe, BEST_MODEL_PKL, compress=3)
            print(">> New best! Saved:", BEST_MODEL_PKL)

        # update progress JSON on Drive
        completed.add(i)
        prog["completed_indices"] = sorted(list(completed))
        prog["best_score"] = best_score
        prog["best_params"] = best_params
        with open(PROGRESS_JSON, "w") as f:
            json.dump(prog, f)
        print("Progress saved to:", PROGRESS_JSON)

        # free memory
        del fitted_pipe; gc.collect()

    except Exception as e:
        print(f"Trial {i+1} failed: {e}")
        # still save progress before stopping/continuing
        prog["completed_indices"] = sorted(list(completed))
        prog["best_score"] = best_score
        prog["best_params"] = best_params
        with open(PROGRESS_JSON, "w") as f:
            json.dump(prog, f)
        break  # or 'continue' if you want to try the next candidate

# summary
if best_params is not None:
    print("\nBest params so far:", best_params)
    print("Best CV avg-RMSE:", -best_score)
    # Optional: reload best model later
    # best_model = joblib.load(BEST_MODEL_PKL)
else:
    print("No successful trials yet.")

print("Best LGB params:", lgb_tuner.best_params_)
print("Best LGB CV avg-RMSE:", -lgb_tuner.best_score_)
# Out:
# Resuming: 0/8 trials completed.
# Checkpoints folder: /content/drive/MyDrive/STLF/Saved_models/lgbm_newsplit
#
# --- Trial 1/8 ---
# Params: {'model__estimator__subsample': 0.7, 'model__estimator__reg_lambda': 0.1, 'model__estimator__reg_alpha': 0.1, 'model__estimator__num_leaves': 127, 'model__estimator__n_estimators': 700, 'model__estimator__min_child_samples': 40, 'model__estimator__max_depth': -1, 'model__estimator__learning_rate': 0.08, 'model__estimator__colsample_bytree': 0.9}
# CV score (avg-neg-RMSE): -336.73368487022674
# >> New best! Saved: /content/drive/MyDrive/STLF/Saved_models/lgbm_newsplit/lgbm_best_model.pkl
# Progress saved to: /content/drive/MyDrive/STLF/Saved_models/lgbm_newsplit/lgbm_tune_progress.json
#
# --- Trial 2/8 ---
# Params: {'model__estimator__subsample': 0.7, 'model__estimator__reg_lambda': 0.1, 'model__estimator__reg_alpha': 0.1, 'model__estimator__num_leaves': 63, 'model__estimator__n_estimators': 700, 'model__estimator__min_child_samples': 20, 'model__estimator__max_depth': 8, 'model__estimator__learning_rate': 0.08, 'model__estimator__colsample_bytree': 0.7}
# CV score (avg-neg-RMSE): -323.4011259674267
# >> New best! Saved: /content/drive/MyDrive/STLF/Saved_models/lgbm_newsplit/lgbm_best_model.pkl
# Progress saved to: /content/drive/MyDrive/STLF/Saved_models/lgbm_newsplit/lgbm_tune_progress.json
#
# --- Trial 3/8 ---
# Params: {'model__estimator__subsample': 0.7, 'model__estimator__reg_lambda': 0.1, 'model__estimator__reg_alpha': 0.0, 'model__estimator__num_leaves': 63, 'model__estimator__n_estimators': 300, 'model__estimator__min_child_samples': 40, 'model__estimator__max_depth': -1, 'model__estimator__learning_rate': 0.08, 'model__estimator__colsample_bytree': 0.9}
# CV score (avg-neg-RMSE): -328.9294502475736
# Progress saved to: /content/drive/MyDrive/STLF/Saved_models/lgbm_newsplit/lgbm_tune_progress.json
#
# --- Trial 4/8 ---
# Params: {'model__estimator__subsample': 0.7, 'model__estimator__reg_lambda': 1.0, 'model__estimator__reg_alpha': 0.0, 'model__estimator__num_leaves': 63, 'model__estimator__n_estimators': 500, 'model__estimator__min_child_samples': 20, 'model__estimator__max_depth': 8, 'model__estimator__learning_rate': 0.08, 'model__estimator__colsample_bytree': 0.9}
# CV score (avg-neg-RMSE): -326.61296258601436
# Progress saved to: /content/drive/MyDrive/STLF/Saved_models/lgbm_newsplit/lgbm_tune_progress.json
#
# --- Trial 5/8 ---
# Params: {'model__estimator__subsample': 0.9, 'model__estimator__reg_lambda': 0.1, 'model__estimator__reg_alpha': 0.0, 'model__estimator__num_leaves': 127, 'model__estimator__n_estimators': 700, 'model__estimator__min_child_samples': 40, 'model__estimator__max_depth': -1, 'model__estimator__learning_rate': 0.05, 'model__estimator__colsample_bytree': 0.9}
# CV score (avg-neg-RMSE): -332.5097688371161
# Progress saved to: /content/drive/MyDrive/STLF/Saved_models/lgbm_newsplit/lgbm_tune_progress.json
#
# --- Trial 6/8 ---
# Params: {'model__estimator__subsample': 0.7, 'model__estimator__reg_lambda': 0.1, 'model__estimator__reg_alpha': 0.1, 'model__estimator__num_leaves': 127, 'model__estimator__n_estimators': 300, 'model__estimator__min_child_samples': 20, 'model__estimator__max_depth': -1, 'model__estimator__learning_rate': 0.08, 'model__estimator__colsample_bytree': 0.7}
# CV score (avg-neg-RMSE): -324.12276318616233
# Progress saved to: /content/drive/MyDrive/STLF/Saved_models/lgbm_newsplit/lgbm_tune_progress.json
#
# --- Trial 7/8 ---
# Params: {'model__estimator__subsample': 0.9, 'model__estimator__reg_lambda': 0.1, 'model__estimator__reg_alpha': 0.0, 'model__estimator__num_leaves': 63, 'model__estimator__n_estimators': 300, 'model__estimator__min_child_samples': 20, 'model__estimator__max_depth': 8, 'model__estimator__learning_rate': 0.05, 'model__estimator__colsample_bytree': 0.7}
# CV score (avg-neg-RMSE): -318.71359346555
# >> New best! Saved: /content/drive/MyDrive/STLF/Saved_models/lgbm_newsplit/lgbm_best_model.pkl
# Progress saved to: /content/drive/MyDrive/STLF/Saved_models/lgbm_newsplit/lgbm_tune_progress.json
#
# --- Trial 8/8 ---
# Params: {'model__estimator__subsample': 0.7, 'model__estimator__reg_lambda': 0.1, 'model__estimator__reg_alpha': 0.0, 'model__estimator__num_leaves': 63, 'model__estimator__n_estimators': 300, 'model__estimator__min_child_samples': 40, 'model__estimator__max_depth': 8, 'model__estimator__learning_rate': 0.08, 'model__estimator__colsample_bytree': 0.7}
# CV score (avg-neg-RMSE): -322.3077872147451
# Progress saved to: /content/drive/MyDrive/STLF/Saved_models/lgbm_newsplit/lgbm_tune_progress.json
#
# Best params so far: {'model__estimator__subsample': 0.9, 'model__estimator__reg_lambda': 0.1, 'model__estimator__reg_alpha': 0.0, 'model__estimator__num_leaves': 63, 'model__estimator__n_estimators': 300, 'model__estimator__min_child_samples': 20, 'model__estimator__max_depth': 8, 'model__estimator__learning_rate': 0.05, 'model__estimator__colsample_bytree': 0.7}
# Best CV avg-RMSE: 318.71359346555
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3024135790.py in <cell line: 0>()
#     151     print("No successful trials yet.")
#     152
# --> 153 print("Best LGB params:", lgb_tuner.best_params_)
#     154 print("Best LGB CV avg-RMSE:", -lgb_tuner.best_score_)
#
# NameError: name 'lgb_tuner' is not defined

# %%
lgb_tuner = joblib.load(BEST_MODEL_PKL)
lgb_tuner
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['Weather', 'Wind Direction',
#                                                    'season', 'is_holiday']),
#                                                  ('num', 'passthrough',
#                                                   ['Temperature',
#                                                    'Precipitation',
#                                                    'Chance of snow', 'Humidity',
#                                                    'Wind', 'Wind Gust',
#                                                    'Wind Degree', 'Cloud Cover',
#                                                    'Visibility', 'is_weekend',
#                                                    'hour', 'dow', 'dom',
#                                                    'month', 'd...
#                                                    'doy_cos', 'y_lag_1',
#                                                    'y_lag_2', 'y_lag_3',
#                                                    'y_lag_4', 'y_lag_5',
#                                                    'y_lag_6', 'y_lag_7',
#                                                    'y_lag_8', 'y_lag_9', ...])])),
#                 ('model',
#                  MultiOutputRegressor(estimator=LGBMRegressor(colsample_bytree=0.7,
#                                                               learning_rate=0.05,
#                                                               max_bin=127,
#                                                               max_depth=8,
#                                                               n_estimators=300,
#                                                               n_jobs=-1,
#                                                               num_leaves=63,
#                                                               objective='regression',
#                                                               random_state=42,
#                                                               reg_lambda=0.1,
#                                                               subsample=0.9,
#                                                               verbose=-1),
#                                       n_jobs=1))])

# %%
with open(os.path.join(BASE_DIR, PROGRESS_JSON), "r") as f:
    prog = json.load(f)
best_params = prog.get("best_params", None)
best_params
# Out:
# {'model__estimator__subsample': 0.9,
#  'model__estimator__reg_lambda': 0.1,
#  'model__estimator__reg_alpha': 0.0,
#  'model__estimator__num_leaves': 63,
#  'model__estimator__n_estimators': 300,
#  'model__estimator__min_child_samples': 20,
#  'model__estimator__max_depth': 8,
#  'model__estimator__learning_rate': 0.05,
#  'model__estimator__colsample_bytree': 0.7}

# %%
# Save best params dictionary to Drive
with open(os.path.join(BASE_DIR, "lgbm_best_params.json"), "w") as f:
    json.dump(best_params, f)
print(">> Saved best params to:", os.path.join(BASE_DIR, "lgbm_best_params.json"))
# Out:
# >> Saved best params to: /content/drive/MyDrive/STLF/Saved_models/lgbm_newsplit/lgbm_best_params.json

# %% [markdown]
# ### Without Z

# %%
# ===== LGB final refit with early stopping (continue from your state) =====
import numpy as np, math, lightgbm as lgb
from sklearn.metrics import mean_squared_error

# 1) map best params from tuner to lgb.train
bp = best_params
g  = lambda k, d=None: bp.get(f"model__estimator__{k}", d)

lgb_params = {
    "seed": 42,                       # master seed (alias: random_state)
    "bagging_seed": 42,
    "feature_fraction_seed": 42,
    "data_random_seed": 42,
    "objective": "regression",
    "metric": "rmse",
    "learning_rate": g("learning_rate", 0.05),
    "num_leaves": g("num_leaves", 127),
    "max_depth": g("max_depth", -1),
    "feature_fraction": g("colsample_bytree", 0.8),   # alias
    "bagging_fraction": g("subsample", 0.8),          # alias
    "bagging_freq": bp.get("model__estimator__subsample_freq", 0),
    "min_data_in_leaf": g("min_child_samples", 20),
    "lambda_l1": g("reg_alpha", 0.0),
    "lambda_l2": g("reg_lambda", 0.1),
    "verbosity": -1,
    "num_threads": -1,
    # Optional GPU:
    # "device_type": "gpu",
    # Optional speed knob during refit:
    "max_bin": 255,
}
# let ES find the best iteration (set bigger than tuned n_estimators)
num_boost_round = 4000
early_stopping_rounds = 100

# 2) encode once
X_trv_enc  = preprocess.fit_transform(X_trv)
X_test_enc = preprocess.transform(X_test)

# 3) carve last 15% of TRV as eval set (keep chronological order)
cut = int(0.85 * X_trv_enc.shape[0])
X_tr, X_ev = X_trv_enc[:cut], X_trv_enc[cut:]
Y_tr, Y_ev = Y_trv[:cut],     Y_trv[cut:]

# 4) train 24 boosters with ES
models_lgb = []
for h in range(HORIZON):
    dtr = lgb.Dataset(X_tr, label=Y_tr[:, h])
    dev = lgb.Dataset(X_ev, label=Y_ev[:, h], reference=dtr)
    booster = lgb.train(
        params=lgb_params,
        train_set=dtr,
        num_boost_round=num_boost_round,
        valid_sets=[dev],
        callbacks=[lgb.early_stopping(early_stopping_rounds), lgb.log_evaluation(-1)]
    )
    models_lgb.append(booster)

# 5) predict & metrics
Y_hat_lgb = np.column_stack([m.predict(X_test_enc, num_iteration=m.best_iteration) for m in models_lgb])

def safe_mape(y_true, y_pred, eps=1e-6):
    y_true = np.asarray(y_true)
    return np.mean(np.abs((y_true - y_pred) / np.clip(np.abs(y_true), eps, None))) * 100.0

rmse_h_lgb = [math.sqrt(mean_squared_error(Y_test[:, h], Y_hat_lgb[:, h])) for h in range(HORIZON)]
nrmse_h_lgb = [rm / (np.mean(Y_test[:, h]) + 1e-6) * 100 for h, rm in enumerate(rmse_h_lgb)]
mape_h_lgb  = [safe_mape(Y_test[:, h], Y_hat_lgb[:, h]) for h in range(HORIZON)]

print("Per-horizon RMSE:", [round(x,2) for x in rmse_h_lgb])
print("Avg RMSE:  {:.3f}".format(np.mean(rmse_h_lgb)))
print("Avg nRMSE: {:.2f}%".format(np.mean(nrmse_h_lgb)))
print("Avg MAPE:  {:.2f}%".format(np.mean(mape_h_lgb)))
# Out:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [220]	valid_0's rmse: 272.223
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [164]	valid_0's rmse: 279.469
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [227]	valid_0's rmse: 270.859
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [328]	valid_0's rmse: 275.509
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [340]	valid_0's rmse: 282.721
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [275]	valid_0's rmse: 277.899
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [248]	valid_0's rmse: 280.969
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [459]	valid_0's rmse: 270.72
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [410]	valid_0's rmse: 278.44
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [363]	valid_0's rmse: 281.738
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [295]	valid_0's rmse: 288.502
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [397]	valid_0's rmse: 292.645
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [303]	valid_0's rmse: 296.793
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [352]	valid_0's rmse: 297.374
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [291]	valid_0's rmse: 295.797
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [255]	valid_0's rmse: 299.544
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [229]	valid_0's rmse: 301.113
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [332]	valid_0's rmse: 298.541
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [304]	valid_0's rmse: 299.073
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [226]	valid_0's rmse: 311.36
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [543]	valid_0's rmse: 309.195
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [375]	valid_0's rmse: 306.486
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [355]	valid_0's rmse: 317.734
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [278]	valid_0's rmse: 322.257
# Per-horizon RMSE: [304.49, 323.85, 289.81, 303.09, 309.4, 292.18, 302.5, 273.16, 289.15, 304.82, 318.18, 332.03, 334.71, 327.54, 314.25, 319.25, 346.02, 313.95, 300.58, 317.14, 312.91, 308.11, 328.41, 325.14]
# Avg RMSE:  312.111
# Avg nRMSE: 12.61%
# Avg MAPE:  9.77%

# %% [markdown]
# ### With future known ahead Z

# %%
# ===== Add known-ahead future covariates Z and train LGB per-horizon =====
import numpy as np, math, lightgbm as lgb
from sklearn.metrics import mean_squared_error

DTYPE = np.float32

# 1) map best params from tuner to lgb.train
bp = best_params
g  = lambda k, d=None: bp.get(f"model__estimator__{k}", d)

lgb_params = {
    "seed": 42,                       # master seed (alias: random_state)
    "bagging_seed": 42,
    "feature_fraction_seed": 42,
    "data_random_seed": 42,
    "objective": "regression",
    "metric": "rmse",
    "learning_rate": g("learning_rate", 0.05),
    "num_leaves": g("num_leaves", 127),
    "max_depth": g("max_depth", -1),
    "feature_fraction": g("colsample_bytree", 0.8),   # alias
    "bagging_fraction": g("subsample", 0.8),          # alias
    "bagging_freq": bp.get("model__estimator__subsample_freq", 0),
    "min_data_in_leaf": g("min_child_samples", 20),
    "lambda_l1": g("reg_alpha", 0.0),
    "lambda_l2": g("reg_lambda", 0.1),
    "verbosity": -1,
    "num_threads": -1,
    # Optional GPU:
    # "device_type": "gpu",
    # Optional speed knob during refit:
    "max_bin": 255,
}

# let ES find the best iteration (set bigger than tuned n_estimators)
num_boost_round = 4000
early_stopping_rounds = 100

def build_future_covariates(times, H, df, TIME_COL):
    # Use ONLY calendar/holiday/season at t+h (no future weather)
    df_key = df[[TIME_COL, 'is_holiday', 'season']].copy()
    df_key[TIME_COL] = pd.to_datetime(df_key[TIME_COL])
    df_key = df_key.set_index(TIME_COL).sort_index()

    Z_list = []
    for ts in times:
        row = []
        for h in range(1, H+1):
            t_h = pd.Timestamp(ts) + pd.Timedelta(hours=h)
            hour = t_h.hour; dow = t_h.dayofweek; doy = t_h.dayofyear
            v = [
                np.sin(2*np.pi*hour/24), np.cos(2*np.pi*hour/24),
                np.sin(2*np.pi*dow/7),  np.cos(2*np.pi*dow/7),
                np.sin(2*np.pi*doy/365.25), np.cos(2*np.pi*doy/365.25),
                1 if dow>=5 else 0,
            ]
            if t_h in df_key.index:
                hol = str(df_key.loc[t_h, 'is_holiday'])
                sea = str(df_key.loc[t_h, 'season'])
            else:
                hol, sea = "False", None  # default if timestamp not present
            hol_vec = [int(hol=="False"), int(hol=="tet"), int(hol=="national")]
            sea_vec = [int(sea==s) for s in ["winter","spring","summer","autumn"]] if sea is not None else [0,0,0,0]
            v += hol_vec + sea_vec
            row.append(v)
        Z_list.append(row)
    return np.array(Z_list, dtype=DTYPE)  # (N, H, Ff)

# 1) Build Z for the EXACT rows of df_feat used by X/Y (same order)
end_times_all = df_feat[TIME_COL].values
Z_all = build_future_covariates(end_times_all, HORIZON, df=df, TIME_COL=TIME_COL)  # (N_feat, H, Ff)

# 2) Slice Z to TRV and TEST to match X_trv / X_test
n_trv = X_trv.shape[0]
Z_trv  = Z_all[:n_trv]         # (N_trv, H, Ff)
Z_test = Z_all[n_trv:]         # (N_test, H, Ff)

# 3) Encode X once (you already did this)
X_trv_enc  = preprocess.fit_transform(X_trv)
X_test_enc = preprocess.transform(X_test)

# 4) Chronological early-stopping split
cut = int(0.85 * X_trv_enc.shape[0])
X_tr_enc,  X_ev_enc  = X_trv_enc[:cut],  X_trv_enc[cut:]
Y_tr_all,  Y_ev_all  = Y_trv[:cut],      Y_trv[cut:]
Z_tr_all,  Z_ev_all  = Z_trv[:cut],      Z_trv[cut:]

# 5) Train 24 LGB boosters, concatenating the matching Z_h slice
models_lgb = []
for h in range(HORIZON):  # h = 0..23 -> t+1..t+24
    Z_tr_h = Z_tr_all[:, h, :]   # (N_tr, Ff)
    Z_ev_h = Z_ev_all[:, h, :]
    Z_te_h = Z_test[:,   h, :]

    Xtr_h = np.hstack([X_tr_enc, Z_tr_h]).astype(DTYPE)
    Xev_h = np.hstack([X_ev_enc, Z_ev_h]).astype(DTYPE)
    Xte_h = np.hstack([X_test_enc, Z_te_h]).astype(DTYPE)

    dtr = lgb.Dataset(Xtr_h, label=Y_tr_all[:, h])
    dev = lgb.Dataset(Xev_h, label=Y_ev_all[:, h], reference=dtr)

    booster = lgb.train(
        params=lgb_params,
        train_set=dtr,
        num_boost_round=num_boost_round,
        valid_sets=[dev],
        callbacks=[lgb.early_stopping(early_stopping_rounds), lgb.log_evaluation(-1)]
    )
    models_lgb.append((booster, Xte_h))

# 6) Predict per-horizon (use each horizon’s Xte_h)
Y_hat_lgb = np.column_stack([
    m.predict(Xh, num_iteration=m.best_iteration) for (m, Xh) in models_lgb
])

# 7) Metrics (same as yours)
def safe_mape(y_true, y_pred, eps=1e-6):
    y_true = np.asarray(y_true)
    return np.mean(np.abs((y_true - y_pred) / np.clip(np.abs(y_true), eps, None))) * 100.0

rmse_h_lgb = [math.sqrt(mean_squared_error(Y_test[:, h], Y_hat_lgb[:, h])) for h in range(HORIZON)]
nrmse_h_lgb = [rm / (np.mean(Y_test[:, h]) + 1e-6) * 100 for h, rm in enumerate(rmse_h_lgb)]
mape_h_lgb  = [safe_mape(Y_test[:, h], Y_hat_lgb[:, h]) for h in range(HORIZON)]

print("Per-horizon RMSE:", [round(x,2) for x in rmse_h_lgb])
print("Avg RMSE:  {:.3f}".format(np.mean(rmse_h_lgb)))
print("Avg nRMSE: {:.2f}%".format(np.mean(nrmse_h_lgb)))
print("Avg MAPE:  {:.2f}%".format(np.mean(mape_h_lgb)))
# Out:
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [179]	valid_0's rmse: 271.428
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [145]	valid_0's rmse: 280.246
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [200]	valid_0's rmse: 267.324
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [215]	valid_0's rmse: 274.969
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [308]	valid_0's rmse: 273.578
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [417]	valid_0's rmse: 275.613
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [268]	valid_0's rmse: 276.878
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [503]	valid_0's rmse: 272.656
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [255]	valid_0's rmse: 276.679
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [245]	valid_0's rmse: 281.641
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [291]	valid_0's rmse: 281.484
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [203]	valid_0's rmse: 289.804
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [306]	valid_0's rmse: 293.554
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [285]	valid_0's rmse: 301.215
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [334]	valid_0's rmse: 294.369
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [201]	valid_0's rmse: 299.28
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [173]	valid_0's rmse: 299.357
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [262]	valid_0's rmse: 294.304
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [275]	valid_0's rmse: 299.075
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [176]	valid_0's rmse: 308.724
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [325]	valid_0's rmse: 305.244
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [445]	valid_0's rmse: 303.605
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [233]	valid_0's rmse: 312.417
# Training until validation scores don't improve for 100 rounds
# Early stopping, best iteration is:
# [212]	valid_0's rmse: 314.82
# Per-horizon RMSE: [302.97, 321.59, 293.2, 300.8, 297.25, 294.43, 297.5, 281.81, 291.76, 302.01, 298.18, 302.74, 313.62, 337.56, 309.05, 320.84, 342.16, 292.6, 283.31, 320.05, 301.1, 306.84, 326.2, 322.27]
# Avg RMSE:  306.660
# Avg nRMSE: 12.39%
# Avg MAPE:  9.58%

# %% [markdown]
# # Results

# %% [markdown]
# ## 70-15-15 split approach

# %%
print("XGBoost Results:")
print("Per-h RMSE:", [round(x,2) for x in rmse_h_xgb])
print("Avg RMSE:  {:.3f}".format(np.mean(rmse_h_xgb)))
print("Avg nRMSE: {:.2f}%".format(np.mean(nrmse_h_xgb)))
print("Avg MAPE:  {:.2f}%".format(np.mean(mape_h_xgb)))
# Out:
# XGBoost Results:
# Per-h RMSE: [296.59, 325.64, 270.0, 270.46, 277.15, 265.78, 267.23, 259.59, 263.36, 274.65, 272.44, 275.65, 289.8, 283.15, 271.81, 291.29, 274.61, 271.92, 265.46, 284.73, 268.49, 266.76, 286.56, 301.62]
# Avg RMSE:  278.114
# Avg nRMSE: 11.85%
# Avg MAPE:  9.00%

# %%
print("LightGB results:")
print("Per-horizon RMSE:", [round(x,2) for x in rmse_h_lgb])
print("Avg RMSE:  {:.3f}".format(np.mean(rmse_h_lgb)))
print("Avg nRMSE: {:.2f}%".format(np.mean(nrmse_h_lgb)))
print("Avg MAPE:  {:.2f}%".format(np.mean(mape_h_lgb)))
# Out:
# LightGB results:
# Per-horizon RMSE: [274.6, 285.04, 273.35, 276.21, 281.96, 273.42, 270.18, 261.52, 271.67, 277.64, 276.35, 277.89, 280.05, 284.98, 276.67, 274.92, 275.68, 273.08, 265.77, 281.67, 272.1, 267.45, 286.04, 295.74]
# Avg RMSE:  276.415
# Avg nRMSE: 11.78%
# Avg MAPE:  8.74%

# %%
Y_hat_xgb.shape, Y_hat_lgb.shape, Y_test.shape
# Out:
# ((7107, 24), (7107, 24), (7107, 24))

# %%
for h in range(HORIZON):
    print(f"xgb_t+{h+1}:", Y_hat_xgb[:, h][0])
    print(f"lgb_t+{h+1}:", Y_hat_lgb[:, h][0])
    print(f"y_true_t+{h+1}:", Y_test[:, h][0])
# Out:
# xgb_t+1: 1988.4346
# lgb_t+1: 2005.6319082389916
# y_true_t+1: 1866.44
# xgb_t+2: 1563.6069
# lgb_t+2: 1556.2699649141357
# y_true_t+2: 1549.87
# xgb_t+3: 1424.0342
# lgb_t+3: 1399.2779444772386
# y_true_t+3: 1372.76
# xgb_t+4: 1391.7781
# lgb_t+4: 1400.8607798082196
# y_true_t+4: 1304.0
# xgb_t+5: 1439.0226
# lgb_t+5: 1467.0696642781
# y_true_t+5: 1304.0
# xgb_t+6: 1655.1913
# lgb_t+6: 1595.92168264926
# y_true_t+6: 1516.86
# xgb_t+7: 1915.626
# lgb_t+7: 1966.0344576286554
# y_true_t+7: 2003.4
# xgb_t+8: 2836.6973
# lgb_t+8: 2878.060269996576
# y_true_t+8: 2938.18
# xgb_t+9: 3604.7205
# lgb_t+9: 3593.8982417774014
# y_true_t+9: 4034.65
# xgb_t+10: 4490.1543
# lgb_t+10: 4495.7502563464195
# y_true_t+10: 4437.05
# xgb_t+11: 4637.315
# lgb_t+11: 4612.101847856309
# y_true_t+11: 4694.4
# xgb_t+12: 4743.7603
# lgb_t+12: 4703.490315495516
# y_true_t+12: 4694.4
# xgb_t+13: 4709.4863
# lgb_t+13: 4699.345637924606
# y_true_t+13: 4694.4
# xgb_t+14: 4733.4927
# lgb_t+14: 4706.422566885368
# y_true_t+14: 4694.4
# xgb_t+15: 4724.5723
# lgb_t+15: 4704.18478239122
# y_true_t+15: 4694.4
# xgb_t+16: 4687.199
# lgb_t+16: 4726.979085192338
# y_true_t+16: 4694.4
# xgb_t+17: 4653.21
# lgb_t+17: 4674.512940350965
# y_true_t+17: 4694.4
# xgb_t+18: 4437.0596
# lgb_t+18: 4599.752838271769
# y_true_t+18: 4456.0
# xgb_t+19: 4280.0586
# lgb_t+19: 4403.617614283391
# y_true_t+19: 3862.61
# xgb_t+20: 3883.6826
# lgb_t+20: 3912.308834293707
# y_true_t+20: 3792.0
# xgb_t+21: 3930.4814
# lgb_t+21: 3910.50774782625
# y_true_t+21: 3963.31
# xgb_t+22: 3512.634
# lgb_t+22: 3512.531950136304
# y_true_t+22: 3999.31
# xgb_t+23: 3064.8394
# lgb_t+23: 3187.823331853072
# y_true_t+23: 3134.34
# xgb_t+24: 2567.5093
# lgb_t+24: 2502.563927402629
# y_true_t+24: 2585.76

# %%
Y_hat_ens = 0.5 * (Y_hat_xgb + Y_hat_lgb)
print("Ensemble Avg RMSE:", np.mean([math.sqrt(mean_squared_error(Y_test[:,h], Y_hat_ens[:,h])) for h in range(24)]))
# Out:
# Ensemble Avg RMSE: 273.89086614940715

# %% [markdown]
# ## Results (8 weeks test set split approach)

# %% [markdown]
# ### without future known ahead Z

# %% [markdown]
# - Per-h RMSE: [300.37, 330.13, 292.41, 301.24, 302.94, 292.55, 290.24, 277.7, 290.68, 316.07, 310.6, 313.78, 313.31, 320.77, 311.67, 323.22, 329.68, 309.68, 294.54, 328.63, 311.57, 291.77, 321.41, 326.5]
# - Avg RMSE:  308.393
# - Avg nRMSE: 12.46%
# - Avg MAPE:  9.66%

# %%
print("Per-horizon RMSE:", [round(x,2) for x in rmse_h_lgb])
print("Avg RMSE:  {:.3f}".format(np.mean(rmse_h_lgb)))
print("Avg nRMSE: {:.2f}%".format(np.mean(nrmse_h_lgb)))
print("Avg MAPE:  {:.2f}%".format(np.mean(mape_h_lgb)))
# Out:
# Per-horizon RMSE: [314.31, 319.83, 302.94, 316.46, 312.66, 294.53, 294.67, 274.53, 296.89, 305.23, 325.58, 310.88, 319.59, 314.39, 309.43, 296.83, 332.86, 311.84, 292.17, 327.73, 302.6, 306.86, 325.9, 329.24]
# Avg RMSE:  309.914
# Avg nRMSE: 12.52%
# Avg MAPE:  9.64%

# %% [markdown]
# ### with  future known ahead Z

# %%
print("Per-h RMSE:", [round(x,2) for x in rmse_h_xgb])
print("Avg RMSE:  {:.3f}".format(np.mean(rmse_h_xgb)))
print("Avg nRMSE: {:.2f}%".format(np.mean(nrmse_h_xgb)))
print("Avg MAPE:  {:.2f}%".format(np.mean(mape_h_xgb)))
# Out:
# Per-h RMSE: [302.92, 324.84, 295.44, 295.63, 298.8, 296.66, 284.81, 269.3, 288.09, 302.5, 307.09, 304.03, 292.25, 326.21, 306.16, 322.76, 327.28, 304.85, 283.7, 324.54, 301.49, 299.43, 329.9, 317.08]
# Avg RMSE:  304.407
# Avg nRMSE: 12.30%
# Avg MAPE:  9.47%

# %%
print("Per-horizon RMSE:", [round(x,2) for x in rmse_h_lgb])
print("Avg RMSE:  {:.3f}".format(np.mean(rmse_h_lgb)))
print("Avg nRMSE: {:.2f}%".format(np.mean(nrmse_h_lgb)))
print("Avg MAPE:  {:.2f}%".format(np.mean(mape_h_lgb)))
# Out:
# Per-horizon RMSE: [302.97, 321.59, 293.2, 300.8, 297.25, 294.43, 297.5, 281.81, 291.76, 302.01, 298.18, 302.74, 313.62, 337.56, 309.05, 320.84, 342.16, 292.6, 283.31, 320.05, 301.1, 306.84, 326.2, 322.27]
# Avg RMSE:  306.660
# Avg nRMSE: 12.39%
# Avg MAPE:  9.58%
